# %%
import numpy as np

a = np.arange(6)

# %%
a.reshape(-1,1)
# Out:
# array([[0],
#        [1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
import pandas as pd

df = pd.read_csv('../population.csv')

# %%
grouped = df.groupby('State_or_UT')['City'].apply(list)
grouped
# Out:
# State_or_UT
# Andhra Pradesh                             [Visakhapatnam, Vijayawada]
# Bihar                                                          [Patna]
# Chhattisgarh                                                  [Raipur]
# Delhi                                                          [Delhi]
# Gujarat                           [Ahmedabad, Surat, Vadodara, Rajkot]
# Haryana                                                    [Faridabad]
# Jammu and Kashmir                                           [Srinagar]
# Jharkhand                                            [Dhanbad, Ranchi]
# Karnataka                                                  [Bengaluru]
# Madhya Pradesh                     [Indore, Bhopal, Jabalpur, Gwalior]
# Maharashtra          [Mumbai, Pune, Nagpur, Thane, Pimpri-Chinchwad...
# Punjab                                            [Ludhiana, Amritsar]
# Rajasthan                                      [Jaipur, Jodhpur, Kota]
# ...

# %%
df = df.head(30)
grouped = df.groupby('State_or_UT')['City'].apply(list)
grouped
# Out:
# State_or_UT
# Andhra Pradesh                                      [Visakhapatnam]
# Bihar                                                       [Patna]
# Delhi                                                       [Delhi]
# Gujarat                        [Ahmedabad, Surat, Vadodara, Rajkot]
# Haryana                                                 [Faridabad]
# Karnataka                                               [Bengaluru]
# Madhya Pradesh                                     [Indore, Bhopal]
# Maharashtra       [Mumbai, Pune, Nagpur, Thane, Pimpri-Chinchwad...
# Punjab                                                   [Ludhiana]
# Rajasthan                                                  [Jaipur]
# Tamil Nadu                                                [Chennai]
# Telangana                                               [Hyderabad]
# Uttar Pradesh     [Lucknow, Kanpur, Ghaziabad, Agra, Meerut, Var...
# West Bengal                                               [Kolkata]
# ...
